# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/a-forty-two/QA_9_MAY_22_BDML/main/titanic.csv")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
df.isna().sum() #no. of null values
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.mean()
# Out:
# C:\Users\2211587\AppData\Local\Temp\21\ipykernel_24436\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\2211587\AppData\Local\Temp\21\ipykernel_24436\222071786.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\2211587\AppData\Local\Temp\21\ipykernel_24436\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# survived       0.486592
# pclass         0.836071
# age           14.526497
# sibsp          1.102743
# parch          0.806057
# fare          49.693429
# adult_male     0.489615
# alone          0.489615
# dtype: float64

# %%
df.value_counts()
# Out:
# survived  pclass  sex     age   sibsp  parch  fare      embarked  class  who    adult_male  deck  embark_town  alive  alone
# 1         1       female  24.0  0      0      69.3000   C         First  woman  False       B     Cherbourg    yes    True     2
#                           58.0  0      0      26.5500   S         First  woman  False       C     Southampton  yes    True     1
#                           49.0  0      0      25.9292   S         First  woman  False       D     Southampton  yes    True     1
#                                 1      0      76.7292   C         First  woman  False       D     Cherbourg    yes    False    1
#                           50.0  0      1      247.5208  C         First  woman  False       B     Cherbourg    yes    False    1
#                                                                                                                               ..
# ...

# %%
df.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.sort_values("fare")
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 271         1       3    male  25.0      0      0    0.0000        S   Third
# 597         0       3    male  49.0      0      0    0.0000        S   Third
# 302         0       3    male  19.0      0      0    0.0000        S   Third
# 633         0       1    male   NaN      0      0    0.0000        S   First
# 277         0       2    male   NaN      0      0    0.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 341         1       1  female  24.0      3      2  263.0000        S   First
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 258         1       1  female  35.0      0      0  512.3292        C   First
# 679         1       1    male  36.0      0      1  512.3292        C   First
#
# ...

# %%
df["sex"].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df.nunique() #by typing this, we can see the counts of unique numbers in each column
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df["embarked"].nunique()
# Out:
# 3

# %%
df[["embarked", "sex"]].nunique()
# Out:
# embarked    3
# sex         2
# dtype: int64

# %%
df["embarked"] = df["embarked"].astype("category")
df["embarked"].dtype
# Out:
# CategoricalDtype(categories=['C', 'Q', 'S'], ordered=False)

# %%
df["embarked"] == "C"
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Name: embarked, Length: 891, dtype: bool

# %%
df_fare_mask = df["fare"] < 100
df_fare_mask
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 886    True
# 887    True
# 888    True
# 889    True
# 890    True
# Name: fare, Length: 891, dtype: bool

# %%
df_sex_mask = df["sex"] == "female"

# %%
df[df_fare_mask & df_sex_mask]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_fare_mask2 = df['fare'] > 500
df_age_mask = df["age"] > 70
df[df_fare_mask2 | df_age_mask]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 96          0       1    male  71.0      0      0   34.6542        C  First
# 116         0       3    male  70.5      0      0    7.7500        Q  Third
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 493         0       1    male  71.0      0      0   49.5042        C  First
# 630         1       1    male  80.0      0      0   30.0000        S  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 851         0       3    male  74.0      0      0    7.7750        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 96     man        True    A    Cherbourg    no   True
# 116    man        True  NaN   Queenstown    no   True
# 258  woman       False  NaN    Cherbourg   yes   True
# 493    man        True  NaN    Cherbourg    no   True
# ...

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[df["age"]>50[["passengerId","sex"]].groupby('sex').agg(['count'])
# Out:
#   Input In [40]
#     df[df["age"]>50[["passengerId","sex"]].groupby('sex').agg(['count'])
#                                                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
df[df['age']>50].groupby('sex').agg(['count','mean'])
# Out:
# C:\Users\2211587\AppData\Local\Temp\21\ipykernel_24436\1968079913.py:1: FutureWarning: ['embarked', 'class', 'who', 'deck', 'embark_town', 'alive'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df[df['age']>50].groupby('sex').agg(['count','mean'])
#        survived           pclass             age            sibsp            \
#           count      mean  count      mean count       mean count      mean
# sex
# female       17  0.941176     17  1.294118    17  56.470588    17  0.588235
# male         47  0.127660     47  1.638298    47  59.531915    47  0.127660
#
#        parch            fare            adult_male      alone
#        count      mean count       mean      count mean count      mean
# sex
# female    17  0.352941    17  67.109312         17  0.0    17  0.352941
# male      47  0.276596    47  35.103194         47  1.0    47  0.787234

# %%
df.loc[df["age"] > 50, [ "age", "sex"]].groupby("sex")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
# Countplot
sns.catplot(x ="sex", hue ="survived",
kind ="count", data = df)

# %%
# Group the dataset by Pclass and Survived and then unstack them
group = df.groupby(['pclass', 'survived'])
pclass_survived = group.size().unstack()
 
# Heatmap - Color encoded 2D representation of data.
sns.heatmap(pclass_survived, annot = True, fmt ="d")
# Out:
# <AxesSubplot:xlabel='survived', ylabel='pclass'>
